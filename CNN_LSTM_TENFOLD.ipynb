# %% [markdown]
# # Step 1: Loading necessary libraries

# %%
import pandas as pd
import numpy as np
import re
import sys
import warnings
from gensim.models.wrappers import FastText
from gensim.models import KeyedVectors
from gensim import models
from sklearn.model_selection import KFold # import KFold
from keras.regularizers import l2
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Model, Sequential
from keras.callbacks import ModelCheckpoint
from keras.layers import Input, Dense, concatenate, Activation, Dropout
from keras.layers.embeddings import Embedding
from keras.layers import Conv1D, GlobalMaxPooling1D, LSTM, Conv1D, Flatten, MaxPooling1D
from keras.callbacks import Callback
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score, roc_auc_score, accuracy_score
warnings.filterwarnings('ignore')
# Out:
# Using TensorFlow backend.
# Using TensorFlow backend.

# %% [markdown]
# # Step 2: Loading pretrained word2vec model

# %%
model_ug_cbow = FastText.load_fasttext_format('../cc.ne.300.bin/cc.ne.300.bin')

# %%
embeddings_index = {}
for w in model_ug_cbow.wv.vocab.keys():
    embeddings_index[w] = model_ug_cbow.wv[w]#np.append(model_ug_cbow.wv[w],model_ug_sg.wv[w])#
print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 584436 word vectors.

# %% [markdown]
# # Step 3: Loading Trained word2vec model

# %%
model_ug_sg = models.Word2Vec.load('../w2v_model_ug_sg.word2vec')
model_ug_cbow = models.Word2Vec.load('../w2v_model_ug_cbow.word2vec')

# %%
embeddings_index = {}
for w in model_ug_cbow.wv.vocab.keys():
    embeddings_index[w] = model_ug_cbow.wv[w]#
print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 42409 word vectors.
# Found 42409 word vectors.

# %% [markdown]
# # Step 4: Loading dataset

# %%
data = pd.read_excel("NepaliEarthquakeTweets_plus_blockade.xlsx",sheetname=0)

# %%
pos_indexes = np.where(data['bhawna']=='p')
neg_indexes = np.where(data['bhawna']=='n')
total_size = 600
size = 600
val_size = 600
df_pos = pd.DataFrame.from_items([('text',data['tweet_text'][pos_indexes[0][0:total_size]]),('target',0)])
df_neg = pd.DataFrame.from_items([('text',data['tweet_text'][neg_indexes[0][0:total_size]]),('target',1)])

df_pos['reply'] = data['reply'][pos_indexes[0][0:total_size]]
df_pos['retweet'] = data['retweet'][pos_indexes[0][0:total_size]]
df_pos['likes'] = data['likes'][pos_indexes[0][0:total_size]]

df_neg['reply'] = data['reply'][neg_indexes[0][0:total_size]]
df_neg['retweet'] = data['retweet'][neg_indexes[0][0:total_size]]
df_neg['likes'] = data['likes'][neg_indexes[0][0:total_size]]

df_pos.index = range(len(df_pos.index))
df_neg.index = range(len(df_neg.index))

df_pos_f = df_pos
df_neg_f = df_neg
df_F = df_pos[0:size]
df_F = df_F.append(df_neg[0:size])
df_F.index = range(len(df_F.index))

len(df_F)
validation_df_F= df_pos[500:600]
validation_df_F = validation_df_F.append(df_neg[500:600])
validation_df_F.index = range(len(validation_df_F.index))
#validation_df

# %%
df = df_pos[0:size]
df = df.append(df_neg[0:size])
df.index = range(len(df.index))
validation_df= df_pos[500:600]
validation_df = validation_df.append(df_neg[500:600])
validation_df.index = range(len(validation_df.index))

# %% [markdown]
# # Step 5: Data Preprocessing: Removing puncuation, english text, decimal

# %%
pat1 = r'@[A-Za-z0-9]+'
pat2 = r'https?://[A-Za-z0-9./]+'
pat3 = r'([@#][A-Za-z0-9]+)'
pat4 = r'.[A-Za-z0-9./]+'
pat5 = r'[\,۔،۔”–’‘‘_!…।-]|(")|(:)|(%)|(ः)|(\u200d)|(\xa0…)|(\u200c\u200c)'
combined_pat = r'|'.join((pat1, pat2,pat3,pat4,pat5))
df['text'] = [re.sub(combined_pat, ' ', x) for x in df['text']]
validation_df['text'] = [re.sub(combined_pat, ' ', x) for x in validation_df['text']]
df_pos['text'] = [re.sub(combined_pat, ' ', x) for x in df_pos['text']]
df_neg['text'] = [re.sub(combined_pat, ' ', x) for x in df_neg['text']]

# %%
kf = KFold(n_splits=10)
print(kf)
# Out:
# KFold(n_splits=10, random_state=None, shuffle=False)
# KFold(n_splits=10, random_state=None, shuffle=False)

# %% [markdown]
# # Step 6: Define Necessary funtions

# %%
def get_train_test(df_pos,df_neg,train_index,test_index):
    X_train = df_pos.text[train_index.tolist()]
    X_train = X_train.append(df_neg.text[train_index.tolist()])
    X_train.index = range(len(X_train.index))
    
    y_train = df_pos.target[train_index.tolist()]
    y_train = y_train.append(df_neg.target[train_index.tolist()])
    y_train.index = range(len(y_train.index))
    
    X_test = df_pos.text[test_index.tolist()]
    X_test = X_test.append(df_neg.text[test_index.tolist()])
    X_test.index = range(len(X_test.index))
    
    y_test = df_pos.target[test_index.tolist()]
    y_test = y_test.append(df_neg.target[test_index.tolist()])
    y_test.index = range(len(y_test.index))
    
    return(X_train,y_train,X_test,y_test)

# %%
class Metrics(Callback):
    def on_train_begin(self, logs={}):
        self.val_f1s = []
        self.val_recalls = []
        self.val_precisions = []

    def on_epoch_end(self, epoch, logs={}):
        val_predict = (np.asarray(self.model.predict(self.model.validation_data[0]))).round()
        val_targ = self.model.validation_data[1]
        _val_f1 = f1_score(val_targ, val_predict)
        _val_recall = recall_score(val_targ, val_predict)
        _val_precision = precision_score(val_targ, val_predict)
        self.val_f1s.append(_val_f1)
        self.val_recalls.append(_val_recall)
        self.val_precisions.append(_val_precision)
        #print(" — val_f1: %f — val_precision: %f — val_recall %f" %(_val_f1, _val_precision, _val_recall))
        return

metrics = Metrics()

# %% [markdown]
# # Step 7: Constructing CNN-LSTM Model

# %%
size = 300
counter = 0
best_test_accuracy = []
after_best_test_accuracy = []
df_pos = df_pos[0:600]
df_neg = df_neg[0:600]
predictedPositive = []
predictedNegative = []
accuracy = []
precision= []
recall = []
roc = [] 
predictedPositive_V = []
predictedNegative_V = []
accuracy_V = []
precision_V= []
recall_V = []
roc_V = [] 
for train_index, test_index in kf.split(df_pos):
    counter = counter +1
    print("=========================================\n")
    print("Fold "+str(counter)+"\n=========================================\n")

    x_train,y_train,x_test,y_test = get_train_test(df_pos,df_neg,train_index,test_index)
    
    x_validation = validation_df['text']
    y_validation = validation_df['target']
      
    tokenizer = Tokenizer(num_words=100000)
    tokenizer.fit_on_texts(x_train)
    sequences = tokenizer.texts_to_sequences(x_train)

    length = []
    for x in x_train:
        length.append(len(x.split()))
    ml = max(length)+10
    
    x_train_seq = pad_sequences(sequences, maxlen=ml)
    
    sequences_val = tokenizer.texts_to_sequences(x_validation)
    x_val_seq = pad_sequences(sequences_val, maxlen=ml)
    
    sequences_test = tokenizer.texts_to_sequences(x_test)
    x_test_seq = pad_sequences(sequences_test, maxlen=ml)
    
    num_words = 100000
    embedding_matrix = np.zeros((num_words, size))
    for word, i in tokenizer.word_index.items():
        if i >= num_words:
            continue
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
            embedding_matrix[i] = embedding_vector
    
    
    #tweet_input = Input(shape=(ml,), dtype='int32')
    tweet_encoder = Embedding(100000, size, weights=[embedding_matrix], input_length=ml, trainable=True)
    
    ######################LSTM##########
    lstm_out = 300
    model = Sequential()
    model.add(tweet_encoder)
    model.add(Conv1D(filters=32, kernel_size=4, activation='relu', padding='causal'))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(0.5))
    model.add(LSTM(units=lstm_out))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    #print(model.summary())
    ####################################
    #model.summary()
    filepath="CNN_best_weights.{epoch:02d}-{val_acc:.4f}.hdf5"
    
    #accuracy = []
    #class TestCallback(Callback):
        #def on_epoch_end(self, epoch, logs={}):
            #accuracy.append(logs.get('val_acc'))
    test_accuracy = []
    test_loss = []
    class TestCallback(Callback):
        def __init__(self, test_data):
            self.test_data = test_data

        def on_epoch_end(self, epoch, logs={}):
            x, y = self.test_data
            loss, acc = self.model.evaluate(x, y, verbose=0)
            #print('\nacc: {}\n'.format(acc))
            test_accuracy.append(acc)
            test_loss.append(loss)
    checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
    callbacks_list = [checkpoint]
    model.fit(x_train_seq, y_train, batch_size=32, epochs=5,
                         validation_data=(x_val_seq, y_validation), callbacks=[TestCallback((x_test_seq, y_test))])
    loss, acc = model.evaluate(x_test_seq, y_test, verbose=0)
    ############################################################################
    predictions = (np.asarray(model.predict(x_val_seq))).round()
    roc_V.append(roc_auc_score(y_validation, predictions))
    accuracy_V.append(accuracy_score(y_validation, predictions, normalize=True))
    precision_V.append(precision_score(y_validation, predictions))
    recall_V.append(recall_score(y_validation, predictions))
    result = pd.DataFrame.from_items([("Actual",y_validation),("Prediction",predictions.tolist())])
    print("Validation Confustion Matrix")
    cm = confusion_matrix(y_validation, predictions)
    print(cm)
    pp = [result['Actual'][x] for x in range(0,len(result)) if ((result['Actual'][x] ==result['Prediction'][x]) and (result['Actual'][x]==0))]
    nn = [result['Actual'][x] for x in range(0,len(result)) if ((result['Actual'][x] ==result['Prediction'][x]) and (result['Actual'][x]==1))]
    predictedPositive_V.append(len(pp))
    predictedNegative_V.append(len(nn))
    ##############################################################################
    ############################################################################
    predictions = (np.asarray(model.predict(x_test_seq))).round()
    roc.append(roc_auc_score(y_test, predictions))
    accuracy.append(accuracy_score(y_test, predictions, normalize=True))
    precision.append(precision_score(y_test, predictions))
    recall.append(recall_score(y_test, predictions))
    result = pd.DataFrame.from_items([("Actual",y_test),("Prediction",predictions.tolist())])
    print("Test Confustion Matrix")
    cm = confusion_matrix(y_test, predictions)
    print(cm)
    pp = [result['Actual'][x] for x in range(0,len(result)) if ((result['Actual'][x] ==result['Prediction'][x]) and (result['Actual'][x]==0))]
    nn = [result['Actual'][x] for x in range(0,len(result)) if ((result['Actual'][x] ==result['Prediction'][x]) and (result['Actual'][x]==1))]
    predictedPositive.append(len(pp))
    predictedNegative.append(len(nn))
    ##############################################################################
    #print('\nAfter 5 epoch Testing loss: {}, acc: {}\n'.format(loss, acc))
    after_best_test_accuracy.append(acc)
    best_test_accuracy.append(max(test_accuracy))    
    

#######################################################################
'''print("##################################################################")
print("Validation Results")
print("##################################################################")
a = sum(accuracy_V)/10
p = sum(precision_V)/10
r = sum(recall_V)/10
ro = sum(roc_V)/10
print("Accuracy: ",a,"\tPrecision: ",p,"\tRecall: ",r,"\tROC: ",ro)
TP = sum(predictedPositive_V)/10
FP = 100-TP
TN = sum(predictedNegative_V)/10
FN = 100-TN
print("Actual Positive: ",len(df_pos),"\tPredictedPositive(TP): ",TP,"\tFP: ",FP)
print("Actual Negative: ",len(df_neg),"\tPredictedNegative(TN): ",TN,"\tFN: ",FN)
F_measure = (2 * p * r)/(p + r)
print("F-measure: "+str(F_measure))'''
##############################################################################
#######################################################################
print("##################################################################")
print("Test Results")
print("##################################################################")
a = sum(accuracy)/10
p = sum(precision)/10
r = sum(recall)/10
ro = sum(roc)/10
print("Accuracy: ",a,"\tPrecision: ",p,"\tRecall: ",r,"\tROC: ",ro)
TP = sum(predictedPositive)
FP = (len(df_pos)-sum(predictedPositive))
TN = sum(predictedNegative)
FN = (len(df_neg)-sum(predictedNegative))
print("Actual Positive: ",len(df_pos),"\tPredictedPositive(TP): ",TP,"\tFP: ",FP)
print("Actual Negative: ",len(df_neg),"\tPredictedNegative(TN): ",TN,"\tFN: ",FN)
F_measure = (2 * p * r)/(p + r)
print("F-measure: "+str(F_measure))
##############################################################################
# Out:
# =========================================
#
# Fold 1
# =========================================
#
# =========================================
#
# Fold 1
# =========================================
#
# Train on 1080 samples, validate on 200 samples
# Epoch 1/5
# Train on 1080 samples, validate on 200 samples
# Epoch 1/5
# 1080/1080 [==============================] - 26s 24ms/step - loss: 0.6623 - accuracy: 0.5889 - val_loss: 0.5581 - val_accuracy: 0.7200
# 1080/1080 [==============================] - 26s 24ms/step - loss: 0.6623 - accuracy: 0.5889 - val_loss: 0.5581 - val_accuracy: 0.7200
# Epoch 2/5
# Epoch 2/5
# 1080/1080 [==============================] - 21s 19ms/step - loss: 0.5145 - accuracy: 0.7657 - val_loss: 0.4299 - val_accuracy: 0.8100
# 1080/1080 [==============================] - 21s 19ms/step - loss: 0.5145 - accuracy: 0.7657 - val_loss: 0.4299 - val_accuracy: 0.8100
# Epoch 3/5
# Epoch 3/5
# 1080/1080 [==============================] - 21s 19ms/step - loss: 0.3563 - accuracy: 0.8537 - val_loss: 0.2190 - val_accuracy: 0.9200
# 1080/1080 [==============================] - 21s 19ms/step - loss: 0.3563 - accuracy: 0.8537 - val_loss: 0.2190 - val_accuracy: 0.9200
# Epoch 4/5
# Epoch 4/5
# 1080/1080 [==============================] - 21s 19ms/step - loss: 0.2705 - accuracy: 0.8880 - val_loss: 0.1383 - val_accuracy: 0.9600
# 1080/1080 [==============================] - 21s 19ms/step - loss: 0.2705 - accuracy: 0.8880 - val_loss: 0.1383 - val_accuracy: 0.9600
# Epoch 5/5
# Epoch 5/5
# 1080/1080 [==============================] - 23s 21ms/step - loss: 0.1956 - accuracy: 0.9259 - val_loss: 0.0713 - val_accuracy: 0.9850
# 1080/1080 [==============================] - 23s 21ms/step - loss: 0.1956 - accuracy: 0.9259 - val_loss: 0.0713 - val_accuracy: 0.9850
# Validation Confustion Matrix
# [[ 97   3]
#  [  0 100]]
# Test Confustion Matrix
# [[30 30]
#  [ 9 51]]
# =========================================
#
# Fold 2
# =========================================
#
# Validation Confustion Matrix
# [[ 97   3]
#  [  0 100]]
# Test Confustion Matrix
# [[30 30]
#  [ 9 51]]
# =========================================
#
# Fold 2
# =========================================
#
# Train on 1080 samples, validate on 200 samples
# Epoch 1/5
# Train on 1080 samples, validate on 200 samples
# Epoch 1/5
# 1080/1080 [==============================] - 24s 22ms/step - loss: 0.6728 - accuracy: 0.5907 - val_loss: 0.5633 - val_accuracy: 0.7150
# 1080/1080 [==============================] - 24s 22ms/step - loss: 0.6728 - accuracy: 0.5907 - val_loss: 0.5633 - val_accuracy: 0.7150
# Epoch 2/5
# Epoch 2/5
# 1080/1080 [==============================] - 21s 20ms/step - loss: 0.5379 - accuracy: 0.7278 - val_loss: 0.3790 - val_accuracy: 0.8350
# 1080/1080 [==============================] - 21s 20ms/step - loss: 0.5379 - accuracy: 0.7278 - val_loss: 0.3790 - val_accuracy: 0.8350
# Epoch 3/5
# Epoch 3/5
# 1080/1080 [==============================] - 19s 18ms/step - loss: 0.3880 - accuracy: 0.8324 - val_loss: 0.2164 - val_accuracy: 0.9300
# 1080/1080 [==============================] - 19s 18ms/step - loss: 0.3880 - accuracy: 0.8324 - val_loss: 0.2164 - val_accuracy: 0.9300
# Epoch 4/5
# Epoch 4/5
# 1080/1080 [==============================] - 23s 21ms/step - loss: 0.3036 - accuracy: 0.8806 - val_loss: 0.1311 - val_accuracy: 0.9650
# 1080/1080 [==============================] - 23s 21ms/step - loss: 0.3036 - accuracy: 0.8806 - val_loss: 0.1311 - val_accuracy: 0.9650
# Epoch 5/5
# Epoch 5/5
# 1080/1080 [==============================] - 23s 21ms/step - loss: 0.1894 - accuracy: 0.9259 - val_loss: 0.0492 - val_accuracy: 0.9950
# 1080/1080 [==============================] - 23s 21ms/step - loss: 0.1894 - accuracy: 0.9259 - val_loss: 0.0492 - val_accuracy: 0.9950
# Validation Confustion Matrix
# [[ 99   1]
#  [  0 100]]
# Test Confustion Matrix
# [[36 24]
#  [21 39]]
# =========================================
#
# Fold 3
# =========================================
#
# Validation Confustion Matrix
# [[ 99   1]
#  [  0 100]]
# Test Confustion Matrix
# [[36 24]
#  [21 39]]
# =========================================
#
# Fold 3
# =========================================
#
# Train on 1080 samples, validate on 200 samples
# Epoch 1/5
# Train on 1080 samples, validate on 200 samples
# Epoch 1/5
# 1080/1080 [==============================] - 24s 22ms/step - loss: 0.6801 - accuracy: 0.5491 - val_loss: 0.5486 - val_accuracy: 0.7600
# 1080/1080 [==============================] - 24s 22ms/step - loss: 0.6801 - accuracy: 0.5491 - val_loss: 0.5486 - val_accuracy: 0.7600
# Epoch 2/5
# Epoch 2/5
# 1080/1080 [==============================] - 22s 20ms/step - loss: 0.5730 - accuracy: 0.6880 - val_loss: 0.4224 - val_accuracy: 0.8200
# 1080/1080 [==============================] - 22s 20ms/step - loss: 0.5730 - accuracy: 0.6880 - val_loss: 0.4224 - val_accuracy: 0.8200
# Epoch 3/5
# Epoch 3/5
# 1080/1080 [==============================] - 21s 20ms/step - loss: 0.4384 - accuracy: 0.8046 - val_loss: 0.2617 - val_accuracy: 0.9000
# 1080/1080 [==============================] - 21s 20ms/step - loss: 0.4384 - accuracy: 0.8046 - val_loss: 0.2617 - val_accuracy: 0.9000
# Epoch 4/5
# Epoch 4/5
# 1080/1080 [==============================] - 20s 18ms/step - loss: 0.3508 - accuracy: 0.8620 - val_loss: 0.1373 - val_accuracy: 0.9750
# 1080/1080 [==============================] - 20s 18ms/step - loss: 0.3508 - accuracy: 0.8620 - val_loss: 0.1373 - val_accuracy: 0.9750
# Epoch 5/5
# Epoch 5/5
# 1080/1080 [==============================] - 20s 18ms/step - loss: 0.2045 - accuracy: 0.9250 - val_loss: 0.0671 - val_accuracy: 0.9850
# 1080/1080 [==============================] - 20s 18ms/step - loss: 0.2045 - accuracy: 0.9250 - val_loss: 0.0671 - val_accuracy: 0.9850
# Validation Confustion Matrix
# [[ 97   3]
#  [  0 100]]
# Test Confustion Matrix
# [[43 17]
#  [ 9 51]]
# =========================================
#
# Fold 4
# =========================================
#
# Validation Confustion Matrix
# [[ 97   3]
#  [  0 100]]
# Test Confustion Matrix
# [[43 17]
#  [ 9 51]]
# =========================================
#
# Fold 4
# =========================================
#
# Train on 1080 samples, validate on 200 samples
# Epoch 1/5
# Train on 1080 samples, validate on 200 samples
# Epoch 1/5
# 1080/1080 [==============================] - 21s 19ms/step - loss: 0.6913 - accuracy: 0.5398 - val_loss: 0.5961 - val_accuracy: 0.6700
# 1080/1080 [==============================] - 21s 19ms/step - loss: 0.6913 - accuracy: 0.5398 - val_loss: 0.5961 - val_accuracy: 0.6700
# Epoch 2/5
# Epoch 2/5
# 1080/1080 [==============================] - 20s 18ms/step - loss: 0.5718 - accuracy: 0.7056 - val_loss: 0.3998 - val_accuracy: 0.8350
# 1080/1080 [==============================] - 20s 18ms/step - loss: 0.5718 - accuracy: 0.7056 - val_loss: 0.3998 - val_accuracy: 0.8350
# Epoch 3/5
# Epoch 3/5
# 1080/1080 [==============================] - 19s 18ms/step - loss: 0.3970 - accuracy: 0.8241 - val_loss: 0.3420 - val_accuracy: 0.8400
# 1080/1080 [==============================] - 19s 18ms/step - loss: 0.3970 - accuracy: 0.8241 - val_loss: 0.3420 - val_accuracy: 0.8400
# Epoch 4/5
# Epoch 4/5
# 1080/1080 [==============================] - 24s 22ms/step - loss: 0.3004 - accuracy: 0.8880 - val_loss: 0.1341 - val_accuracy: 0.9700
# 1080/1080 [==============================] - 24s 22ms/step - loss: 0.3004 - accuracy: 0.8880 - val_loss: 0.1341 - val_accuracy: 0.9700
# Epoch 5/5
# Epoch 5/5
# 1080/1080 [==============================] - 26s 24ms/step - loss: 0.2123 - accuracy: 0.9269 - val_loss: 0.0909 - val_accuracy: 0.9850
# 1080/1080 [==============================] - 26s 24ms/step - loss: 0.2123 - accuracy: 0.9269 - val_loss: 0.0909 - val_accuracy: 0.9850
# Validation Confustion Matrix
# [[ 97   3]
#  [  0 100]]
# Test Confustion Matrix
# [[46 14]
#  [21 39]]
# =========================================
#
# Fold 5
# =========================================
#
# Validation Confustion Matrix
# [[ 97   3]
#  [  0 100]]
# Test Confustion Matrix
# [[46 14]
#  [21 39]]
# =========================================
#
# Fold 5
# =========================================
#
# Train on 1080 samples, validate on 200 samples
# Epoch 1/5
# Train on 1080 samples, validate on 200 samples
# Epoch 1/5
# 1080/1080 [==============================] - 22s 20ms/step - loss: 0.6901 - accuracy: 0.5574 - val_loss: 0.5914 - val_accuracy: 0.7350
# 1080/1080 [==============================] - 22s 20ms/step - loss: 0.6901 - accuracy: 0.5574 - val_loss: 0.5914 - val_accuracy: 0.7350
# Epoch 2/5
# Epoch 2/5
# 1080/1080 [==============================] - 23s 21ms/step - loss: 0.5573 - accuracy: 0.7093 - val_loss: 0.3778 - val_accuracy: 0.8400
# 1080/1080 [==============================] - 23s 21ms/step - loss: 0.5573 - accuracy: 0.7093 - val_loss: 0.3778 - val_accuracy: 0.8400
# Epoch 3/5
# Epoch 3/5
# 1080/1080 [==============================] - 20s 19ms/step - loss: 0.4296 - accuracy: 0.7954 - val_loss: 0.2976 - val_accuracy: 0.8950
# 1080/1080 [==============================] - 20s 19ms/step - loss: 0.4296 - accuracy: 0.7954 - val_loss: 0.2976 - val_accuracy: 0.8950
# Epoch 4/5
# Epoch 4/5
# 1080/1080 [==============================] - 20s 19ms/step - loss: 0.3178 - accuracy: 0.8750 - val_loss: 0.1091 - val_accuracy: 0.9750
# 1080/1080 [==============================] - 20s 19ms/step - loss: 0.3178 - accuracy: 0.8750 - val_loss: 0.1091 - val_accuracy: 0.9750
# Epoch 5/5
# Epoch 5/5
# 1080/1080 [==============================] - 20s 19ms/step - loss: 0.1960 - accuracy: 0.9259 - val_loss: 0.1018 - val_accuracy: 0.9750
# 1080/1080 [==============================] - 20s 19ms/step - loss: 0.1960 - accuracy: 0.9259 - val_loss: 0.1018 - val_accuracy: 0.9750
# Validation Confustion Matrix
# [[ 95   5]
#  [  0 100]]
# Test Confustion Matrix
# [[39 21]
#  [22 38]]
# =========================================
#
# Fold 6
# =========================================
#
# Validation Confustion Matrix
# [[ 95   5]
#  [  0 100]]
# Test Confustion Matrix
# [[39 21]
#  [22 38]]
# =========================================
#
# Fold 6
# =========================================
#
# Train on 1080 samples, validate on 200 samples
# Epoch 1/5
# Train on 1080 samples, validate on 200 samples
# Epoch 1/5
# 1080/1080 [==============================] - 21s 19ms/step - loss: 0.6718 - accuracy: 0.5806 - val_loss: 0.5606 - val_accuracy: 0.7250
# 1080/1080 [==============================] - 21s 19ms/step - loss: 0.6718 - accuracy: 0.5806 - val_loss: 0.5606 - val_accuracy: 0.7250
# Epoch 2/5
# Epoch 2/5
# 1080/1080 [==============================] - 23s 21ms/step - loss: 0.5424 - accuracy: 0.7250 - val_loss: 0.4243 - val_accuracy: 0.8200
# 1080/1080 [==============================] - 23s 21ms/step - loss: 0.5424 - accuracy: 0.7250 - val_loss: 0.4243 - val_accuracy: 0.8200
# Epoch 3/5
# Epoch 3/5
# 1080/1080 [==============================] - 23s 21ms/step - loss: 0.4412 - accuracy: 0.8028 - val_loss: 0.3061 - val_accuracy: 0.8950
# 1080/1080 [==============================] - 23s 21ms/step - loss: 0.4412 - accuracy: 0.8028 - val_loss: 0.3061 - val_accuracy: 0.8950
# Epoch 4/5
# Epoch 4/5
# 1080/1080 [==============================] - 27s 25ms/step - loss: 0.3138 - accuracy: 0.8722 - val_loss: 0.1633 - val_accuracy: 0.9600
# 1080/1080 [==============================] - 27s 25ms/step - loss: 0.3138 - accuracy: 0.8722 - val_loss: 0.1633 - val_accuracy: 0.9600
# Epoch 5/5
# Epoch 5/5
# 1080/1080 [==============================] - 22s 20ms/step - loss: 0.2097 - accuracy: 0.9185 - val_loss: 0.0905 - val_accuracy: 0.9850
# 1080/1080 [==============================] - 22s 20ms/step - loss: 0.2097 - accuracy: 0.9185 - val_loss: 0.0905 - val_accuracy: 0.9850
# Validation Confustion Matrix
# [[99  1]
#  [ 2 98]]
# Test Confustion Matrix
# [[53  7]
#  [22 38]]
# =========================================
#
# Fold 7
# =========================================
#
# Validation Confustion Matrix
# [[99  1]
#  [ 2 98]]
# Test Confustion Matrix
# [[53  7]
#  [22 38]]
# =========================================
#
# Fold 7
# =========================================
#
# Train on 1080 samples, validate on 200 samples
# Epoch 1/5
# Train on 1080 samples, validate on 200 samples
# Epoch 1/5
# 1080/1080 [==============================] - 27s 25ms/step - loss: 0.6623 - accuracy: 0.5935 - val_loss: 0.5503 - val_accuracy: 0.7350
# 1080/1080 [==============================] - 27s 25ms/step - loss: 0.6623 - accuracy: 0.5935 - val_loss: 0.5503 - val_accuracy: 0.7350
# Epoch 2/5
# Epoch 2/5
# 1080/1080 [==============================] - 24s 22ms/step - loss: 0.5526 - accuracy: 0.7139 - val_loss: 0.4801 - val_accuracy: 0.7650
# 1080/1080 [==============================] - 24s 22ms/step - loss: 0.5526 - accuracy: 0.7139 - val_loss: 0.4801 - val_accuracy: 0.7650
# Epoch 3/5
# Epoch 3/5
# 1080/1080 [==============================] - 22s 20ms/step - loss: 0.4211 - accuracy: 0.8065 - val_loss: 0.2574 - val_accuracy: 0.8900
# 1080/1080 [==============================] - 22s 20ms/step - loss: 0.4211 - accuracy: 0.8065 - val_loss: 0.2574 - val_accuracy: 0.8900
# Epoch 4/5
# Epoch 4/5
# 1080/1080 [==============================] - 20s 19ms/step - loss: 0.2849 - accuracy: 0.8861 - val_loss: 0.1075 - val_accuracy: 0.9750
# 1080/1080 [==============================] - 20s 19ms/step - loss: 0.2849 - accuracy: 0.8861 - val_loss: 0.1075 - val_accuracy: 0.9750
# Epoch 5/5
# Epoch 5/5
# 1080/1080 [==============================] - 21s 20ms/step - loss: 0.2097 - accuracy: 0.9250 - val_loss: 0.0584 - val_accuracy: 0.9900
# 1080/1080 [==============================] - 21s 20ms/step - loss: 0.2097 - accuracy: 0.9250 - val_loss: 0.0584 - val_accuracy: 0.9900
# Validation Confustion Matrix
# [[ 98   2]
#  [  0 100]]
# Test Confustion Matrix
# [[45 15]
#  [22 38]]
# =========================================
#
# Fold 8
# =========================================
#
# Validation Confustion Matrix
# [[ 98   2]
#  [  0 100]]
# Test Confustion Matrix
# [[45 15]
#  [22 38]]
# =========================================
#
# Fold 8
# =========================================
#
# Train on 1080 samples, validate on 200 samples
# Epoch 1/5
# Train on 1080 samples, validate on 200 samples
# Epoch 1/5
# 1080/1080 [==============================] - 26s 24ms/step - loss: 0.6844 - accuracy: 0.5574 - val_loss: 0.6100 - val_accuracy: 0.6750
# 1080/1080 [==============================] - 26s 24ms/step - loss: 0.6844 - accuracy: 0.5574 - val_loss: 0.6100 - val_accuracy: 0.6750
# Epoch 2/5
# Epoch 2/5
# 1080/1080 [==============================] - 22s 21ms/step - loss: 0.5763 - accuracy: 0.6954 - val_loss: 0.4094 - val_accuracy: 0.8150
# 1080/1080 [==============================] - 22s 21ms/step - loss: 0.5763 - accuracy: 0.6954 - val_loss: 0.4094 - val_accuracy: 0.8150
# Epoch 3/5
# Epoch 3/5
# 1080/1080 [==============================] - 22s 20ms/step - loss: 0.4097 - accuracy: 0.8157 - val_loss: 0.2669 - val_accuracy: 0.8650
# 1080/1080 [==============================] - 22s 20ms/step - loss: 0.4097 - accuracy: 0.8157 - val_loss: 0.2669 - val_accuracy: 0.8650
# Epoch 4/5
# Epoch 4/5
# 1080/1080 [==============================] - 21s 19ms/step - loss: 0.3014 - accuracy: 0.8704 - val_loss: 0.1656 - val_accuracy: 0.9500
# 1080/1080 [==============================] - 21s 19ms/step - loss: 0.3014 - accuracy: 0.8704 - val_loss: 0.1656 - val_accuracy: 0.9500
# Epoch 5/5
# Epoch 5/5
# 1080/1080 [==============================] - 21s 20ms/step - loss: 0.1983 - accuracy: 0.9250 - val_loss: 0.0511 - val_accuracy: 0.9950
# 1080/1080 [==============================] - 21s 20ms/step - loss: 0.1983 - accuracy: 0.9250 - val_loss: 0.0511 - val_accuracy: 0.9950
# Validation Confustion Matrix
# [[ 99   1]
#  [  0 100]]
# Test Confustion Matrix
# [[36 24]
#  [19 41]]
# =========================================
#
# Fold 9
# =========================================
#
# Validation Confustion Matrix
# [[ 99   1]
#  [  0 100]]
# Test Confustion Matrix
# [[36 24]
#  [19 41]]
# =========================================
#
# Fold 9
# =========================================
#
# Train on 1080 samples, validate on 200 samples
# Epoch 1/5
# Train on 1080 samples, validate on 200 samples
# Epoch 1/5
# 1080/1080 [==============================] - 24s 22ms/step - loss: 0.6951 - accuracy: 0.5583 - val_loss: 0.6007 - val_accuracy: 0.6750
# 1080/1080 [==============================] - 24s 22ms/step - loss: 0.6951 - accuracy: 0.5583 - val_loss: 0.6007 - val_accuracy: 0.6750
# Epoch 2/5
# Epoch 2/5
# 1080/1080 [==============================] - 24s 22ms/step - loss: 0.5680 - accuracy: 0.7102 - val_loss: 0.5443 - val_accuracy: 0.7050
# 1080/1080 [==============================] - 24s 22ms/step - loss: 0.5680 - accuracy: 0.7102 - val_loss: 0.5443 - val_accuracy: 0.7050
# Epoch 3/5
# Epoch 3/5
# 1080/1080 [==============================] - 23s 21ms/step - loss: 0.4273 - accuracy: 0.8083 - val_loss: 0.6566 - val_accuracy: 0.6900
# 1080/1080 [==============================] - 23s 21ms/step - loss: 0.4273 - accuracy: 0.8083 - val_loss: 0.6566 - val_accuracy: 0.6900
# Epoch 4/5
# Epoch 4/5
# 1080/1080 [==============================] - 21s 19ms/step - loss: 0.2950 - accuracy: 0.8796 - val_loss: 0.3616 - val_accuracy: 0.8400
# 1080/1080 [==============================] - 21s 19ms/step - loss: 0.2950 - accuracy: 0.8796 - val_loss: 0.3616 - val_accuracy: 0.8400
# Epoch 5/5
# Epoch 5/5
# 1080/1080 [==============================] - 20s 19ms/step - loss: 0.2105 - accuracy: 0.9167 - val_loss: 0.3464 - val_accuracy: 0.8450
# 1080/1080 [==============================] - 20s 19ms/step - loss: 0.2105 - accuracy: 0.9167 - val_loss: 0.3464 - val_accuracy: 0.8450
# Validation Confustion Matrix
# [[82 18]
#  [13 87]]
# Test Confustion Matrix
# [[34 26]
#  [16 44]]
# =========================================
#
# Fold 10
# =========================================
#
# Validation Confustion Matrix
# [[82 18]
#  [13 87]]
# Test Confustion Matrix
# [[34 26]
#  [16 44]]
# =========================================
#
# Fold 10
# =========================================
#
# Train on 1080 samples, validate on 200 samples
# Epoch 1/5
# Train on 1080 samples, validate on 200 samples
# Epoch 1/5
# 1080/1080 [==============================] - 23s 21ms/step - loss: 0.6841 - accuracy: 0.5611 - val_loss: 0.6179 - val_accuracy: 0.6450
# 1080/1080 [==============================] - 23s 21ms/step - loss: 0.6841 - accuracy: 0.5611 - val_loss: 0.6179 - val_accuracy: 0.6450
# Epoch 2/5
# Epoch 2/5
# 1080/1080 [==============================] - 22s 21ms/step - loss: 0.5346 - accuracy: 0.7296 - val_loss: 0.6406 - val_accuracy: 0.6850
# 1080/1080 [==============================] - 22s 21ms/step - loss: 0.5346 - accuracy: 0.7296 - val_loss: 0.6406 - val_accuracy: 0.6850
# Epoch 3/5
# Epoch 3/5
# 1080/1080 [==============================] - 22s 21ms/step - loss: 0.4129 - accuracy: 0.8194 - val_loss: 0.6660 - val_accuracy: 0.6750
# 1080/1080 [==============================] - 22s 21ms/step - loss: 0.4129 - accuracy: 0.8194 - val_loss: 0.6660 - val_accuracy: 0.6750
# Epoch 4/5
# Epoch 4/5
# 1080/1080 [==============================] - 22s 21ms/step - loss: 0.2883 - accuracy: 0.8815 - val_loss: 0.6159 - val_accuracy: 0.7600
# 1080/1080 [==============================] - 22s 21ms/step - loss: 0.2883 - accuracy: 0.8815 - val_loss: 0.6159 - val_accuracy: 0.7600
# Epoch 5/5
# Epoch 5/5
# 1080/1080 [==============================] - 25s 23ms/step - loss: 0.1723 - accuracy: 0.9398 - val_loss: 0.7031 - val_accuracy: 0.7750
# 1080/1080 [==============================] - 25s 23ms/step - loss: 0.1723 - accuracy: 0.9398 - val_loss: 0.7031 - val_accuracy: 0.7750
# Validation Confustion Matrix
# [[65 35]
#  [10 90]]
# Test Confustion Matrix
# [[25 35]
#  [10 50]]
# ##################################################################
# Test Results
# ##################################################################
# Accuracy:  0.6799999999999999 	Precision:  0.6787595631869413 	Recall:  0.7150000000000001 	ROC:  0.6799999999999999
# Actual Positive:  600 	PredictedPositive(TP):  387 	FP:  213
# Actual Negative:  600 	PredictedNegative(TN):  429 	FN:  171
# F-measure: 0.696408620966096
# Validation Confustion Matrix
# [[65 35]
#  [10 90]]
# Test Confustion Matrix
# [[25 35]
#  [10 50]]
# ##################################################################
# Test Results
# ##################################################################
# Accuracy:  0.6799999999999999 	Precision:  0.6787595631869413 	Recall:  0.7150000000000001 	ROC:  0.6799999999999999
# Actual Positive:  600 	PredictedPositive(TP):  387 	FP:  213
# Actual Negative:  600 	PredictedNegative(TN):  429 	FN:  171
# F-measure: 0.696408620966096

# %% [markdown]
# # Result of CNN-LSTM + Trained Word2Vec

# %% [raw]
# ##################################################################
# Test Results
# ##################################################################
# Accuracy:  0.6799999999999999 	Precision:  0.6787595631869413 	Recall:  0.7150000000000001 	ROC:  0.6799999999999999
# Actual Positive:  600 	PredictedPositive(TP):  387 	FP:  213
# Actual Negative:  600 	PredictedNegative(TN):  429 	FN:  171
# F-measure: 0.696408620966096

# %% [markdown]
# # Result of CNN-LSTM + Pretrained word2vec

# %% [raw]
# =========================================
#
# Fold 1
# =========================================
#
# Train on 1080 samples, validate on 200 samples
# Epoch 1/5
# 1080/1080 [==============================] - 24s 22ms/step - loss: 0.6878 - accuracy: 0.5463 - val_loss: 0.6417 - val_accuracy: 0.7600
# Epoch 2/5
# 1080/1080 [==============================] - 23s 21ms/step - loss: 0.4730 - accuracy: 0.8194 - val_loss: 0.1404 - val_accuracy: 0.9650
# Epoch 3/5
# 1080/1080 [==============================] - 22s 20ms/step - loss: 0.1274 - accuracy: 0.9722 - val_loss: 0.0737 - val_accuracy: 0.9850
# Epoch 4/5
# 1080/1080 [==============================] - 21s 19ms/step - loss: 0.0431 - accuracy: 0.9926 - val_loss: 0.0201 - val_accuracy: 0.9950
# Epoch 5/5
# 1080/1080 [==============================] - 21s 20ms/step - loss: 0.0121 - accuracy: 0.9981 - val_loss: 0.0280 - val_accuracy: 0.9950
# Validation Confustion Matrix
# [[ 99   1]
#  [  0 100]]
# Test Confustion Matrix
# [[41 19]
#  [18 42]]
# =========================================
#
# Fold 2
# =========================================
#
# Train on 1080 samples, validate on 200 samples
# Epoch 1/5
# 1080/1080 [==============================] - 22s 21ms/step - loss: 0.6875 - accuracy: 0.5593 - val_loss: 0.6504 - val_accuracy: 0.7600
# Epoch 2/5
# 1080/1080 [==============================] - 21s 20ms/step - loss: 0.5238 - accuracy: 0.7963 - val_loss: 0.1839 - val_accuracy: 0.9400
# Epoch 3/5
# 1080/1080 [==============================] - 22s 20ms/step - loss: 0.1335 - accuracy: 0.9620 - val_loss: 0.1368 - val_accuracy: 0.9750
# Epoch 4/5
# 1080/1080 [==============================] - 22s 21ms/step - loss: 0.0433 - accuracy: 0.9944 - val_loss: 0.0379 - val_accuracy: 0.9950
# Epoch 5/5
# 1080/1080 [==============================] - 22s 21ms/step - loss: 0.0138 - accuracy: 0.9972 - val_loss: 0.0395 - val_accuracy: 0.9950
# Validation Confustion Matrix
# [[ 99   1]
#  [  0 100]]
# Test Confustion Matrix
# [[41 19]
#  [26 34]]
# =========================================
#
# Fold 3
# =========================================
#
# Train on 1080 samples, validate on 200 samples
# Epoch 1/5
# 1080/1080 [==============================] - 23s 22ms/step - loss: 0.6909 - accuracy: 0.5213 - val_loss: 0.6592 - val_accuracy: 0.6300
# Epoch 2/5
# 1080/1080 [==============================] - 22s 21ms/step - loss: 0.5584 - accuracy: 0.7426 - val_loss: 0.2233 - val_accuracy: 0.9550
# Epoch 3/5
# 1080/1080 [==============================] - 21s 20ms/step - loss: 0.1491 - accuracy: 0.9620 - val_loss: 0.0702 - val_accuracy: 0.9850
# Epoch 4/5
# 1080/1080 [==============================] - 21s 20ms/step - loss: 0.0539 - accuracy: 0.9889 - val_loss: 0.0500 - val_accuracy: 0.9950
# Epoch 5/5
# 1080/1080 [==============================] - 23s 21ms/step - loss: 0.0150 - accuracy: 0.9981 - val_loss: 0.0275 - val_accuracy: 0.9950
# Validation Confustion Matrix
# [[ 99   1]
#  [  0 100]]
# Test Confustion Matrix
# [[46 14]
#  [22 38]]
# =========================================
#
# Fold 4
# =========================================
#
# Train on 1080 samples, validate on 200 samples
# Epoch 1/5
# 1080/1080 [==============================] - 22s 20ms/step - loss: 0.6908 - accuracy: 0.5389 - val_loss: 0.6577 - val_accuracy: 0.7200
# Epoch 2/5
# 1080/1080 [==============================] - 23s 21ms/step - loss: 0.5653 - accuracy: 0.7463 - val_loss: 0.2650 - val_accuracy: 0.9450
# Epoch 3/5
# 1080/1080 [==============================] - 23s 21ms/step - loss: 0.1737 - accuracy: 0.9556 - val_loss: 0.0742 - val_accuracy: 0.9850
# Epoch 4/5
# 1080/1080 [==============================] - 23s 21ms/step - loss: 0.0438 - accuracy: 0.9926 - val_loss: 0.0468 - val_accuracy: 0.9900
# Epoch 5/5
# 1080/1080 [==============================] - 21s 19ms/step - loss: 0.0239 - accuracy: 0.9963 - val_loss: 0.0244 - val_accuracy: 0.9950
# Validation Confustion Matrix
# [[ 99   1]
#  [  0 100]]
# Test Confustion Matrix
# [[50 10]
#  [33 27]]
# =========================================
#
# Fold 5
# =========================================
#
# Train on 1080 samples, validate on 200 samples
# Epoch 1/5
# 1080/1080 [==============================] - 25s 23ms/step - loss: 0.6904 - accuracy: 0.5370 - val_loss: 0.6660 - val_accuracy: 0.7400
# Epoch 2/5
# 1080/1080 [==============================] - 24s 22ms/step - loss: 0.5593 - accuracy: 0.7676 - val_loss: 0.2105 - val_accuracy: 0.9500
# Epoch 3/5
# 1080/1080 [==============================] - 23s 21ms/step - loss: 0.1517 - accuracy: 0.9583 - val_loss: 0.0505 - val_accuracy: 0.9850
# Epoch 4/5
# 1080/1080 [==============================] - 24s 22ms/step - loss: 0.0410 - accuracy: 0.9880 - val_loss: 0.0431 - val_accuracy: 0.9950
# Epoch 5/5
# 1080/1080 [==============================] - 22s 21ms/step - loss: 0.0184 - accuracy: 0.9981 - val_loss: 0.0303 - val_accuracy: 0.9950
# Validation Confustion Matrix
# [[ 99   1]
#  [  0 100]]
# Test Confustion Matrix
# [[50 10]
#  [25 35]]
# =========================================
#
# Fold 6
# =========================================
#
# Train on 1080 samples, validate on 200 samples
# Epoch 1/5
# 1080/1080 [==============================] - 24s 22ms/step - loss: 0.6906 - accuracy: 0.5352 - val_loss: 0.6578 - val_accuracy: 0.7050
# Epoch 2/5
# 1080/1080 [==============================] - 23s 21ms/step - loss: 0.5249 - accuracy: 0.7731 - val_loss: 0.2566 - val_accuracy: 0.9050
# Epoch 3/5
# 1080/1080 [==============================] - 23s 21ms/step - loss: 0.1615 - accuracy: 0.9528 - val_loss: 0.1026 - val_accuracy: 0.9850
# Epoch 4/5
# 1080/1080 [==============================] - 25s 23ms/step - loss: 0.0461 - accuracy: 0.9926 - val_loss: 0.0387 - val_accuracy: 0.9950
# Epoch 5/5
# 1080/1080 [==============================] - 24s 22ms/step - loss: 0.0221 - accuracy: 0.9963 - val_loss: 0.0186 - val_accuracy: 0.9950
# Validation Confustion Matrix
# [[ 99   1]
#  [  0 100]]
# Test Confustion Matrix
# [[43 17]
#  [21 39]]
# =========================================
#
# Fold 7
# =========================================
#
# Train on 1080 samples, validate on 200 samples
# Epoch 1/5
# 1080/1080 [==============================] - 26s 24ms/step - loss: 0.6962 - accuracy: 0.4954 - val_loss: 0.6818 - val_accuracy: 0.5150
# Epoch 2/5
# 1080/1080 [==============================] - 22s 21ms/step - loss: 0.6196 - accuracy: 0.7000 - val_loss: 0.2886 - val_accuracy: 0.9100
# Epoch 3/5
# 1080/1080 [==============================] - 24s 22ms/step - loss: 0.2305 - accuracy: 0.9278 - val_loss: 0.0692 - val_accuracy: 0.9900
# Epoch 4/5
# 1080/1080 [==============================] - 22s 20ms/step - loss: 0.0475 - accuracy: 0.9917 - val_loss: 0.0468 - val_accuracy: 0.9950
# Epoch 5/5
# 1080/1080 [==============================] - 23s 21ms/step - loss: 0.0220 - accuracy: 0.9991 - val_loss: 0.0186 - val_accuracy: 0.9950
# Validation Confustion Matrix
# [[ 99   1]
#  [  0 100]]
# Test Confustion Matrix
# [[45 15]
#  [26 34]]
# =========================================
#
# Fold 8
# =========================================
#
# Train on 1080 samples, validate on 200 samples
# Epoch 1/5
# 1080/1080 [==============================] - 27s 25ms/step - loss: 0.6858 - accuracy: 0.5500 - val_loss: 0.6107 - val_accuracy: 0.6300
# Epoch 2/5
# 1080/1080 [==============================] - 22s 20ms/step - loss: 0.4679 - accuracy: 0.8028 - val_loss: 0.1440 - val_accuracy: 0.9550
# Epoch 3/5
# 1080/1080 [==============================] - 21s 19ms/step - loss: 0.1296 - accuracy: 0.9685 - val_loss: 0.0539 - val_accuracy: 0.9950
# Epoch 4/5
# 1080/1080 [==============================] - 21s 19ms/step - loss: 0.0478 - accuracy: 0.9917 - val_loss: 0.0092 - val_accuracy: 1.0000
# Epoch 5/5
# 1080/1080 [==============================] - 23s 21ms/step - loss: 0.0233 - accuracy: 0.9963 - val_loss: 0.0073 - val_accuracy: 1.0000
# Validation Confustion Matrix
# [[100   0]
#  [  0 100]]
# Test Confustion Matrix
# [[50 10]
#  [28 32]]
# =========================================
#
# Fold 9
# =========================================
#
# Train on 1080 samples, validate on 200 samples
# Epoch 1/5
# 1080/1080 [==============================] - 23s 21ms/step - loss: 0.6918 - accuracy: 0.5204 - val_loss: 0.6729 - val_accuracy: 0.6700
# Epoch 2/5
# 1080/1080 [==============================] - 20s 19ms/step - loss: 0.5757 - accuracy: 0.7546 - val_loss: 0.4744 - val_accuracy: 0.7500
# Epoch 3/5
# 1080/1080 [==============================] - 22s 20ms/step - loss: 0.1968 - accuracy: 0.9417 - val_loss: 0.3881 - val_accuracy: 0.8300
# Epoch 4/5
# 1080/1080 [==============================] - 22s 20ms/step - loss: 0.0487 - accuracy: 0.9926 - val_loss: 0.3987 - val_accuracy: 0.8250
# Epoch 5/5
# 1080/1080 [==============================] - 21s 20ms/step - loss: 0.0314 - accuracy: 0.9972 - val_loss: 0.4341 - val_accuracy: 0.8250
# Validation Confustion Matrix
# [[82 18]
#  [17 83]]
# Test Confustion Matrix
# [[33 27]
#  [22 38]]
# =========================================
#
# Fold 10
# =========================================
#
# Train on 1080 samples, validate on 200 samples
# Epoch 1/5
# 1080/1080 [==============================] - 25s 23ms/step - loss: 0.6913 - accuracy: 0.5231 - val_loss: 0.6797 - val_accuracy: 0.5100
# Epoch 2/5
# 1080/1080 [==============================] - 22s 21ms/step - loss: 0.5404 - accuracy: 0.7704 - val_loss: 0.4630 - val_accuracy: 0.7750
# Epoch 3/5
# 1080/1080 [==============================] - 24s 22ms/step - loss: 0.1618 - accuracy: 0.9667 - val_loss: 0.5004 - val_accuracy: 0.7950
# Epoch 4/5
# 1080/1080 [==============================] - 21s 19ms/step - loss: 0.0390 - accuracy: 0.9907 - val_loss: 0.6386 - val_accuracy: 0.7950
# Epoch 5/5
# 1080/1080 [==============================] - 23s 21ms/step - loss: 0.0113 - accuracy: 0.9991 - val_loss: 0.7965 - val_accuracy: 0.7800
# Validation Confustion Matrix
# [[73 27]
#  [17 83]]
# Test Confustion Matrix
# [[33 27]
#  [17 43]]
# ##################################################################
# Test Results
# ##################################################################
# Accuracy:  0.6616666666666667 	Precision:  0.6919422745657776 	Recall:  0.6033333333333333 	ROC:  0.6616666666666667
# Actual Positive:  600 	PredictedPositive(TP):  432 	FP:  168
# Actual Negative:  600 	PredictedNegative(TN):  362 	FN:  238
# F-measure: 0.6446069646368822
